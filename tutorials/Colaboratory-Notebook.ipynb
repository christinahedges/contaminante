# %%
git clone --single-branch --branch refactor-sparse https://github.com/christinahedges/lightkurve
# Out:
# Requirement already satisfied: contaminante in /Users/ch/K2/projects/contaminante (0.1.dev0)
# Requirement already satisfied: numpy>=1.11 in /Users/ch/miniconda3/lib/python3.6/site-packages (from contaminante) (1.18.2)
# Requirement already satisfied: astropy>=1.3 in /Users/ch/miniconda3/lib/python3.6/site-packages (from contaminante) (4.0.1.post1)
# Collecting scipy!=1.4.0,!=1.4.1,>=0.19.0 (from contaminante)
#   Downloading https://files.pythonhosted.org/packages/eb/48/ed472bd27722b1ff81c210bfb30b93780569571b9e947d207dc2d403ea28/scipy-1.3.3-cp36-cp36m-macosx_10_6_intel.whl (27.8MB)
#     9% |███▏                            | 2.8MB 1.6MB/s eta 0:00:16

# %%
! pip install contaminante

# %%
import contaminante

# %%
# Note the contaminante version should be >0.2
contaminante.__version__
# Out:
# '0.1.dev'

# %%
# The target name, either KIC, EPIC or TIC ID
targetid = 'KIC 6804648'
# Mission name, either kepler, K2 or tess
mission='kepler'

# Orbital period in days
period = 0.700606

# Transit midpoint in days
t0 = 131.59767

# Duration in days
duration = 0.993/24

# %%
fig, result = contaminante.calculate_contamination(targetid=targetid,
                               period=period,
                               t0=t0,
                               duration=duration,
                               mission=mission)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-2af4839aabee> in <module>()
#       3                                t0=t0,
#       4                                duration=duration,
# ----> 5                                mission=mission)
#
# ~/K2/projects/contaminante/contaminante/utils.py in calculate_contamination(targetid, period, t0, duration, mission, plot, gaia, quarter, sector, campaign, bin_points)
#     287             raise ValueError('No target pixel files exist for {} from {}'.format(targetid, mission))
#     288         else:
# --> 289             tpfs = sr.download_all()
#     290         contaminator = None
#     291         target = None
#
# ~/K2/repos/lightkurve/lightkurve/utils.py in wrapper(*args, **kwargs)
#     477             sys.stdout = devnull
#     478             try:
# --> 479                 return f(*args, **kwargs)
#     480             # restore to default
#     481             finally:
#
# ~/K2/repos/lightkurve/lightkurve/search.py in download_all(self, quality_bitmask, download_dir, cutout_size)
#     291                                                quality_bitmask=quality_bitmask,
#     292                                                download_dir=download_dir,
# --> 293                                                cutout_size=cutout_size))
#     294         if isinstance(products[0], TargetPixelFile):
#     295             return TargetPixelFileCollection(products)
#
# ~/K2/repos/lightkurve/lightkurve/search.py in _download_one(self, table, quality_bitmask, download_dir, cutout_size)
#     174             log.debug("Started downloading {}.".format(table[:1]['dataURL'][0]))
#     175             path = Observations.download_products(table[:1], mrp_only=False,
# --> 176                                                   download_dir=download_dir)['Local Path'][0]
#     177             log.debug("Finished downloading.")
#     178             # open() will determine filetype and return
#
# ~/miniconda3/lib/python3.6/site-packages/astroquery/mast/core.py in download_products(self, products, download_dir, cache, curl_flag, mrp_only, **filters)
#    1858         else:
#    1859             base_dir = download_dir.rstrip('/') + "/mastDownload"
# -> 1860             manifest = self._download_files(products, base_dir, cache)
#    1861
#    1862         return manifest
#
# ~/miniconda3/lib/python3.6/site-packages/astroquery/mast/core.py in _download_files(self, products, base_dir, cache)
#    1773                         self._download_file(data_url, local_path, cache=cache, head_safe=True, continuation=False)
#    1774                 else:
# -> 1775                     self._download_file(data_url, local_path, cache=cache, head_safe=True, continuation=False)
#    1776
#    1777                 # check if file exists also this is where would perform md5,
#
# ~/miniconda3/lib/python3.6/site-packages/astroquery/query.py in _download_file(self, url, local_filepath, timeout, auth, continuation, cache, method, head_safe, **kwargs)
#     273         if head_safe:
#     274             response = self._session.request("HEAD", url, timeout=timeout, stream=True,
# --> 275                                              auth=auth, **kwargs)
#     276         else:
#     277             response = self._session.request(method, url, timeout=timeout, stream=True,
#
# ~/miniconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/miniconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/miniconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~/miniconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/miniconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/miniconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/miniconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/miniconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/miniconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/miniconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/miniconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1712             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1713         else:
# -> 1714             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1715         self._raise_ssl_error(self._ssl, result)
#    1716
#
# KeyboardInterrupt:

# %%
result
